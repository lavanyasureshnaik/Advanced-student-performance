# %%
import numpy as np
import pandas as pd
import seaborn as sns

# %%
data = pd.read_excel('data.xlsx')
data.salary = data.salary*1000

# %%
data.info
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 123 entries, 0 to 122
# Data columns (total 14 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   satisfaction_level     123 non-null    int64
#  1   last_evaluation        123 non-null    int64
#  2   number_project         123 non-null    int64
#  3   average_montly_hours   123 non-null    int64
#  4   time_spen_company      123 non-null    int64
#  5   work_accident          123 non-null    int64
#  6   exit                   123 non-null    int64
#  7   promotion_last_5years  123 non-null    int64
#  8   sales                  123 non-null    int64
#  9   salary                 123 non-null    int64
#  10  Internships            123 non-null    int64
#  11  Training               123 non-null    int64
#  12  Backlog                123 non-null    int64
#  13  result                 123 non-null    int64
# dtypes: int64(14)
# memory usage: 13.6 KB

# %% [markdown]
# # no missing data
# # no categorical data

# %%
data.describe()
# Out:
#        satisfaction_level   last_evaluation  number_project  \
# count           123.000000       123.000000      123.000000
# mean             43.609756        42.211382       40.186992
# std              25.943708        25.182043       26.936279
# min               5.000000         7.000000        1.000000
# 25%              24.000000        21.000000       17.000000
# 50%              36.000000        34.000000       31.000000
# 75%              63.500000        64.000000       65.000000
# max              95.000000        97.000000       91.000000
#
#        average_montly_hours  time_spen_company  work_accident        exit  \
# count            123.000000         123.000000     123.000000  123.000000
# mean              41.105691          48.284553      46.154472   42.528455
# std               21.385154          24.885811      25.126575   23.071992
# min               10.000000          10.000000      11.000000   10.000000
# 25%               24.000000          26.000000      25.000000   21.000000
# 50%               31.000000          42.000000      35.000000   40.000000
# 75%               56.000000          74.000000      74.000000   63.000000
# max               93.000000          90.000000      93.000000   92.000000
#
#        promotion_last_5years       sales        salary  Internships  \
# count             123.000000  123.000000    123.000000   123.000000
# mean               41.065041   45.739837  41967.479675    41.691057
# std                23.420511   27.335750  24956.333983    22.561802
# min                11.000000    4.000000  10000.000000     0.000000
# 25%                18.000000   21.000000  17000.000000    25.000000
# 50%                40.000000   47.000000  46000.000000    35.000000
# 75%                57.500000   74.000000  63000.000000    62.000000
# max                94.000000   90.000000  90000.000000    91.000000
#
#          Training     Backlog      result
# count  123.000000  123.000000  123.000000
# mean    45.008130    2.512195   47.016260
# std     23.867289    3.707250   25.530112
# min      0.000000    0.000000   10.000000
# 25%     23.000000    0.000000   25.000000
# 50%     47.000000    1.000000   45.000000
# 75%     65.000000    4.000000   68.000000
# max     90.000000   23.000000   96.000000

# %%
data.head()
# Out:
#    satisfaction_level   last_evaluation  number_project  average_montly_hours  \
# 0                   85               85              90                    30
# 1                   89               90              85                    35
# 2                   80               85              90                    45
# 3                   95               90              90                    20
# 4                   95               85              80                    75
#
#    time_spen_company  work_accident  exit  promotion_last_5years  sales  \
# 0                 40             75    40                     40     75
# 1                 50             80    40                     35     70
# 2                 55             85    45                     45     78
# 3                 40             80    30                     30     60
# 4                 80             90    70                     80     88
#
#    salary  Internships  Training  Backlog  result
# 0   80000           80        85        0      52
# 1   70000           75        80        0      44
# 2   85000           80        80        0      60
# 3   70000            0         0        0      30
# 4   90000           80        80        0      95

# %%
data.tail()
# Out:
#      satisfaction_level   last_evaluation  number_project  \
# 118                   58               59              68
# 119                   59               58              62
# 120                   66               52              68
# 121                   62               65              62
# 122                   64               64              61
#
#      average_montly_hours  time_spen_company  work_accident  exit  \
# 118                    59                 79             84    64
# 119                    58                 80             86    65
# 120                    54                 84             78    63
# 121                    55                 81             49    64
# 122                    52                 80             74    65
#
#      promotion_last_5years  sales  salary  Internships  Training  Backlog  \
# 118                     57     74      49           47        68        0
# 119                     59     78      48           48        64        1
# 120                     58     50      46           47        64        2
# 121                     56     78      45           49        61        0
# 122                     41     50      41           51        52        1
#
#      result
# 118      85
# 119      75
# 120      64
# 121      66
# 122      74

# %%
data.sample(10)
# Out:
#      satisfaction_level   last_evaluation  number_project  \
# 101                   36               34              25
# 54                    26               29              16
# 108                   48               41              22
# 24                    84               82              80
# 120                   66               52              68
# 75                     5               17              23
# 48                    17               21              21
# 13                    88               90              80
# 104                   45               35              27
# 52                    21               24              18
#
#      average_montly_hours  time_spen_company  work_accident  exit  \
# 101                    24                 30             27    21
# 54                     34                 29             25    30
# 108                    25                 32             26    29
# 24                     77                 74             58    49
# 120                    54                 84             78    63
# 75                     23                 20             23    16
# 48                     25                 26             34    20
# 13                     86                 81             91    89
# 104                    27                 34             24    24
# 52                     36                 24             31    25
#
#      promotion_last_5years  sales  salary  Internships  Training  Backlog  \
# 101                     41     24      17           32        42        1
# 54                      25     21      13           31        22        7
# 108                     26     29      15           25        25        1
# 24                      65     69      48           47        60        0
# 120                     58     50      46           47        64        2
# 75                      18     21      17           19         9        8
# 48                      12     21      25           28        23        4
# 13                      82     81      82           91        80        0
# 104                     42     26      17           30        37        0
# 52                      22     24      16           28        26        3
#
#      result
# 101      35
# 54       26
# 108      30
# 24       67
# 120      64
# 75       31
# 48       26
# 13       93
# 104      37
# 52       25

# %%
# dependent and independent varisble
X = data.iloc[:,:10]
y = data.iloc[:,-1]

# %%
X
# Out:
#      satisfaction_level   last_evaluation  number_project  \
# 0                     85               85              90
# 1                     89               90              85
# 2                     80               85              90
# 3                     95               90              90
# 4                     95               85              80
# ..                   ...              ...             ...
# 118                   58               59              68
# 119                   59               58              62
# 120                   66               52              68
# 121                   62               65              62
# 122                   64               64              61
#
#      average_montly_hours  time_spen_company  work_accident  exit  \
# 0                      30                 40             75    40
# 1                      35                 50             80    40
# 2                      45                 55             85    45
# 3                      20                 40             80    30
# 4                      75                 80             90    70
# ..                    ...                ...            ...   ...
# 118                    59                 79             84    64
# 119                    58                 80             86    65
# 120                    54                 84             78    63
# 121                    55                 81             49    64
# 122                    52                 80             74    65
#
#      promotion_last_5years  sales  salary
# 0                       40     75   80000
# 1                       35     70   70000
# 2                       45     78   85000
# 3                       30     60   70000
# 4                       80     88   90000
# ..                     ...    ...     ...
# 118                     57     74   49000
# 119                     59     78   48000
# 120                     58     50   46000
# 121                     56     78   45000
# 122                     41     50   41000
#
# [123 rows x 10 columns]

# %%
y
# Out:
# 0      52
# 1      44
# 2      60
# 3      30
# 4      95
#        ..
# 118    85
# 119    75
# 120    64
# 121    66
# 122    74
# Name: result, Length: 123, dtype: int64

# %%
from sklearn.model_selection import train_test_split

# %%
X_train , X_test , Y_train , Y_test = train_test_split(X,y,test_size=0.2,random_state=100)

# %% [markdown]
# # Linear Regression

# %%
from sklearn.linear_model import LinearRegression

# %%
reg = LinearRegression().fit(X_train, Y_train)

# %%
score_lr = reg.score(X_test, Y_test)
score_lr= score_lr * 100

# %% [markdown]
# # Random Forest

# %%
from sklearn.ensemble import RandomForestRegressor

# %%
regr = RandomForestRegressor(max_depth=3, random_state=0)

# %%
regr.fit(X_train, Y_train)
# Out:
# RandomForestRegressor(max_depth=3, random_state=0)

# %%
score_rf = regr.score(X_test,Y_test)
score_rf =score_rf*100

# %%
scores = [score_lr,score_rf]
algorithems = ['linear regressor','random regressor']

for i in range(len(algorithems)):
    print('the accuracy score achieved usinf'+algorithems[i]+'is :'+str(scores[i])+" %")
# Out:
# the accuracy score achieved usinflinear regressoris :80.73578854112347 %
# the accuracy score achieved usinfrandom regressoris :87.07366592966557 %

# %%
import matplotlib.pyplot as plt
sns.set(rc={'figure.figsize':(15,8)})
plt.xlabel('algo')
plt.ylabel('score')

sns.barplot(algorithems,scores)
# Out:
# C:\Users\HP\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='algo', ylabel='score'>
